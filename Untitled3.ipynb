# %% [markdown]
# <a href="https://colab.research.google.com/github/sheyda-06/detectionvision1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.3/107.7 GB disk)

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 84434, done.
# remote: Total 84434 (delta 0), reused 0 (delta 0), pack-reused 84434 (from 1)
# Receiving objects: 100% (84434/84434), 44.78 MiB | 22.83 MiB/s, done.
# Resolving deltas: 100% (63821/63821), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
# Run inference on an image with YOLO26n
# !yolo predict model=yolo26n.pt source=/fruits.jpg
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# image 1/1 /fruits.jpg: 448x640 2 bananas, 2 apples, 2 oranges, 169.8ms
# Speed: 14.7ms preprocess, 169.8ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/ultralytics/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
