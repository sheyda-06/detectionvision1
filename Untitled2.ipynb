# %% [markdown]
# <a href="https://colab.research.google.com/github/sheyda-06/detectionvision1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.3/107.7 GB disk)

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %pip install -qe ultralytics
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
# Run inference on an image with YOLO26n
# !yolo predict model=yolo26n.pt source=/content/renklibalonlar.jpeg
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# image 1/1 /content/renklibalonlar.jpeg: 640x544 1 apple, 1 orange, 200.2ms
# Speed: 9.2ms preprocess, 200.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to /content/runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
