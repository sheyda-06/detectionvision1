# %% [markdown]
# <a href="https://colab.research.google.com/github/sheyda-06/Untitled1.ipynb/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.8/112.6 GB disk)

# %%
# Git clone method (for development)
# !git clone https://github.com/ultralytics/ultralytics
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 84434, done.
# remote: Total 84434 (delta 0), reused 0 (delta 0), pack-reused 84434 (from 1)
# Receiving objects: 100% (84434/84434), 44.66 MiB | 21.33 MiB/s, done.
# Resolving deltas: 100% (63867/63867), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %%
# Run inference on an image with YOLO26n
# !yolo predict model=yolo26n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# Found https://ultralytics.com/images/zidane.jpg locally at zidane.jpg
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 55.6ms
# Speed: 3.0ms preprocess, 55.6ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
